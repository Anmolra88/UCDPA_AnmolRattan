# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization
import re

# %%
# Making a sample example with all the variations of the date.
dateStr = "23-10-2002\n23/10/2002\n23/10/02\n10/23/2002\n23 Oct 2002\n23 October 2002\nOct 23, 2002\nOctober 23, 2002\n"
print(dateStr)
# Out:
# 23-10-2002
# 23/10/2002
# 23/10/02
# 10/23/2002
# 23 Oct 2002
# 23 October 2002
# Oct 23, 2002
# October 23, 2002

# %%
re.findall(r'\d{2}[/-]\d{2}[/-]\d{4}', dateStr)
# Out:
# ['23-10-2002', '23/10/2002', '10/23/2002']

# %%
df = pd.read_csv("C:/Users/anmol/UCDPA_Anmol Rattan/Heart Attack Prediction/heart.csv")

# %%
df.loc[(df['sex'] ==1), 'sex'] = 'Man'
df.loc[(df['sex'] ==0), 'sex'] = 'Woman'

df.loc[(df['output'] ==1), 'output'] = 'High'
df.loc[(df['output'] ==0), 'output'] = 'Low'

df.head()
# Out:
#    age    sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    Man   3     145   233    1        0       150     0      2.3    0
# 1   37    Man   2     130   250    0        1       187     0      3.5    0
# 2   41  Woman   1     130   204    0        0       172     0      1.4    2
# 3   56    Man   1     120   236    0        1       178     0      0.8    2
# 4   57  Woman   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall output
# 0    0      1   High
# 1    0      2   High
# 2    0      2   High
# 3    0      2   High
# 4    0      2   High

# %%
df.loc[(df['sex'] =='Man'), 'sex'] = 1
df.loc[(df['sex'] =='Woman'), 'sex'] = 0

df.loc[(df['output'] =='High'), 'output'] = '1'
df.loc[(df['output'] =='Low'), 'output'] = '0'

df.head()
# Out:
#    age sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# 0   63   1   3     145   233    1        0       150     0      2.3    0    0
# 1   37   1   2     130   250    0        1       187     0      3.5    0    0
# 2   41   0   1     130   204    0        0       172     0      1.4    2    0
# 3   56   1   1     120   236    0        1       178     0      0.8    2    0
# 4   57   0   0     120   354    0        1       163     1      0.6    2    0
#
#    thall output
# 0      1      1
# 1      2      1
# 2      2      1
# 3      2      1
# 4      2      1

# %%
df = pd.read_csv("C:/Users/anmol/UCDPA_Anmol Rattan/Heart Attack Prediction/heart.csv")
df.sort_values("age").head()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 72    29    1   1     130   204    0        0       202     0      0.0    2
# 58    34    1   3     118   182    0        0       174     0      0.0    2
# 125   34    0   1     118   210    0        1       192     0      0.7    2
# 239   35    1   0     126   282    0        0       156     1      0.0    2
# 65    35    0   0     138   183    0        1       182     0      1.4    2
#
#      caa  thall  output
# 72     0      2       1
# 58     0      2       1
# 125    0      2       1
# 239    0      3       0
# 65     0      2       1

# %%
# Labelling data fields to Text value for easy interpretation of Visualization
data_eda = df.copy()

data_eda["sex"]     = df["sex"]    .map({1: "Male",           0: "Female"})
data_eda["cp"]      = df["cp"]     .map({1: "Typical\nangina", 2: "Atypical\nangina", 3:"Non-anginal\npain", 0: "Asymptomatic"})
data_eda["fbs"]     = df["fbs"]    .map({1: "True",           0: "False"})
data_eda["restecg"] = df["restecg"].map({1: "Normal",         2: "Having\nST-T wave\nabnormality",          0: "Hypertrophy"})
data_eda["exng"]    = df["exng"]   .map({1: "Yes" ,           0: "No"})
data_eda["slp"]     = df["slp"]    .map({2: "Upsloping",      1: "Flat" ,           0: "Downsloping"})
data_eda["caa"]     = df["caa"]    .map({0: "0",              1: "1" ,              2: "2",               3:"3" ,4:"3"})
data_eda["thall"]   = df["thall"]  .map({0: "Normal",         2: "Normal" ,         1: "Fixed defect" ,   3: "Reversible\ndefect"})
data_eda["output"]  = df["output"] .map({1: "Yes" ,           0: "No"})

# %%
data_eda.sort_values("age").head()
# Out:
#      age     sex                 cp  trtbps  chol    fbs      restecg  \
# 72    29    Male    Typical\nangina     130   204  False  Hypertrophy
# 58    34    Male  Non-anginal\npain     118   182  False  Hypertrophy
# 125   34  Female    Typical\nangina     118   210  False       Normal
# 239   35    Male       Asymptomatic     126   282  False  Hypertrophy
# 65    35  Female       Asymptomatic     138   183  False       Normal
#
#      thalachh exng  oldpeak        slp caa               thall output
# 72        202   No      0.0  Upsloping   0              Normal    Yes
# 58        174   No      0.0  Upsloping   0              Normal    Yes
# 125       192   No      0.7  Upsloping   0              Normal    Yes
# 239       156  Yes      0.0  Upsloping   0  Reversible\ndefect     No
# 65        182   No      1.4  Upsloping   0              Normal    Yes

# %%
import pandas as pd
read_html=pd.read_html("https://www.imdb.com/chart/top/")   # pandas powerful code line for reading tables in html pages
data=read_html[0]                                           # read_html returns list item. First item of that list returns pandas dataframe
data
# Out:
#      Unnamed: 0                          Rank & Title  IMDb Rating  \
# 0           NaN  1.  The Shawshank Redemption  (1994)          9.2
# 1           NaN             2.  The Godfather  (1972)          9.2
# 2           NaN           3.  The Dark Knight  (2008)          9.0
# 3           NaN     4.  The Godfather Part II  (1974)          9.0
# 4           NaN              5.  12 Angry Men  (1957)          9.0
# ..          ...                                   ...          ...
# 245         NaN             246.  Dersu Uzala  (1975)          8.0
# 246         NaN                 247.  Aladdin  (1992)          8.0
# 247         NaN                248.  The Help  (2011)          8.0
# 248         NaN                  249.  Gandhi  (1982)          8.0
# 249         NaN          250.  The Iron Giant  (1999)          8.0
#
#                             Your Rating  Unnamed: 4
# 0    12345678910 NOT YET RELEASED  Seen         NaN
# 1    12345678910 NOT YET RELEASED  Seen         NaN
# ...

# %%
import urllib.request

# %%
url = "https://en.wikipedia.org/wiki/List_of_original_programs_distributed_by_Netflix"

# %%
page = urllib.request.urlopen(url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page, "lxml")

# %%
all_tables=soup.find_all("table",class_='wikitable sortable')
all_tables
# Out:
# [<table class="wikitable sortable" style="width:100%">
#  <tbody><tr>
#  <th>Title
#  </th>
#  <th>Genre
#  </th>
#  <th>Premiere
#  </th>
#  <th>Seasons
#  </th>
#  <th>Runtime
#  </th>
#  <th>Status
#  </th></tr>
#  <tr>
#  <td><i><a href="/wiki/Stranger_Things" title="Stranger Things">Stranger Things</a></i>
#  </td>
#  <td><a href="/wiki/Science_fiction_on_television" title="Science fiction on television">Science fiction</a> <a href="/wiki/Horror_fiction" title="Horror fiction">horror</a>
#  </td>
#  <td>July 15, 2016
#  </td>
#  <td><span data-sort-value="34 !">4 seasons, 34 episodes</span>
#  </td>
#  <td><span data-sort-value="42 !">42–150 min</span>
#  </td>
#  <td>Renewed for final season<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
#  </td></tr>
#  <tr>
#  <td><i><a href="/wiki/The_Crown_(TV_series)" title="The Crown (TV series)">The Crown</a></i>
#  </td>
#  <td><a href="/wiki/Historical_drama" title="Historical drama">Historical drama</a>
# ...

# %%
Title=[]
Genre=[]
Premiere=[]
Seasons=[]
Length=[]
Status=[]

# %%
for table in range(len(all_tables)):
    for row in all_tables[table].find_all("tr"):
        cells=row.findAll('td')
        if len(cells)==6:
            Title.append(cells[0].find(text=True))
            Genre.append(cells[1].find(text=True))
            Premiere.append(cells[2].find(text=True))
            Seasons.append(cells[3].find(text=True))
            Length.append(cells[4].find(text=True))
            Status.append(cells[5].find(text=True))

# %%
import pandas as pd

df=pd.DataFrame(Title,columns=['Title'])
df['Genre']=Genre
df['Original Network'] ='Netflix'
df['Premiere']=Premiere
df['Seasons']=Seasons
df['Length']=Length
df['Netflix Exclusive Regions']='Worldwide'
df['Status']=Status

# %%
df
# Out:
#                                    Title             Genre Original Network  \
# 0                        Stranger Things   Science fiction          Netflix
# 1                              The Crown  Historical drama          Netflix
# 2                   The Umbrella Academy         Superhero          Netflix
# 3                           Virgin River    Romantic drama          Netflix
# 4                            The Witcher           Fantasy          Netflix
# ..                                   ...               ...              ...
# 154  The Life and Movies of Erşan Kuneri            Sitcom          Netflix
# 155                    As the Crow Flies             Drama          Netflix
# 156                         Another Self             Drama          Netflix
# 157                         Man on Pause            Comedy          Netflix
# 158                            Hot Skull   Science fiction          Netflix
#
# ...

# %%
Title=[]
Genre=[]
Original_Network=[]
Premiere=[]
Seasons=[]
Length=[]
Netflix_Exclusive_Regions=[]
Status=[]

# %%
for table in range(len(all_tables)):
    for row in all_tables[table].find_all("tr"):
        cells=row.findAll('td')
        if len(cells)==8:
            Title.append(cells[0].find(text=True))
            Genre.append(cells[1].find(text=True))
            Original_Network.append(cells[2].find(text=True))
            Premiere.append(cells[3].find(text=True))
            Seasons.append(cells[4].find(text=True))
            Length.append(cells[5].find(text=True))
            Netflix_Exclusive_Regions.append(cells[6].find(text=True))
            Status.append(cells[7].find(text=True))

# %%
df2=pd.DataFrame(Title,columns=['Title'])
df2['Genre']=Genre
df2['Original Network']=Original_Network
df2['Premiere']=Premiere
df2['Seasons']=Seasons
df2['Length']=Length
df2['Netflix Exclusive Regions']=Netflix_Exclusive_Regions
df2['Status']=Status

# %%
df2.head(27)
# Out:
#                                         Title                   Genre  \
# 0                                Black Mirror         Science fiction
# 1         Inside the World's Toughest Prisons              Docuseries
# 2                                     Top Boy             Crime drama
# 3                                         You  Psychological thriller
# 4                          Unsolved Mysteries              Docuseries
# 5                                   Cobra Kai            Martial arts
# 6                                  Blown Away                 Reality
# 7                                    The Mire                Thriller
# 8                               Tiger & Bunny                   Anime
# 9                                    The Mole     Reality competition
# 10                                   Manifest            Supernatural
# 11                                Teletubbies               Preschool
# ...

# %%
netflix_originals = pd.concat([df,df2.head(27)])

# %%
netflix_originals
# Out:
#                                         Title             Genre  \
# 0                             Stranger Things   Science fiction
# 1                                   The Crown  Historical drama
# 2                        The Umbrella Academy         Superhero
# 3                                Virgin River    Romantic drama
# 4                                 The Witcher           Fantasy
# ..                                        ...               ...
# 12                                     Arcane          Animated
# 13  Oggy and the Cockroaches: Next Generation          Animated
# 14                          Diary of a Gigolo          Thriller
# 15                              The Nutty Boy          Animated
# 16                            The Final Score             Drama
#
#        Original Network               Premiere                 Seasons  \
# 0               Netflix        July 15, 2016\n  4 seasons, 34 episodes
# ...

# %%
netflix_originals.to_csv ('netflix_originals.csv', index = False, header=True)
